# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
report = pd.read_excel('Book1.xlsx')
report
# Out:
#             NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 0          GAURI     69     80.0     70.0  72.0   60.0
# 1         MUSKAN     89     98.0     90.0  76.0   92.0
# 2         ANJALI     76     72.0     74.0  76.0   98.0
# 3         ARMAAN     76     74.0     73.0  73.0   76.0
# 4   ANJALI YADAV     74     87.0     76.0  71.0   98.0
# 5         AREEBA     76     50.0     65.0  77.0   76.0
# 6        NANDANI     98     89.0     76.0  76.0   54.0
# 7           IRAM     87     69.0     67.0  58.0   76.0
# 8         AASTHA     65     65.0     75.0  68.0   86.0
# 9         RITIMA     60     53.0     71.0  67.0   90.0
# 10      RITAKSHI     65     86.0     69.0  70.0   87.0
# 11          JAYA     65     76.0     70.0  76.0   80.0
# 12         KRITI     67     89.0     60.0  78.0   78.0
# 13       ANAMIKA     98     67.0     78.0  87.0   98.0
# 14        SARIKA     90     45.0     75.0  87.0   60.0
# 15           NaN     77      NaN      NaN   NaN    NaN
# ...

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NAME     15 non-null     object
#  1   MATHS    17 non-null     int64
#  2   ENGLISH  15 non-null     float64
#  3   SCIENCE  15 non-null     float64
#  4   EVS      15 non-null     float64
#  5   HINDI    15 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 944.0+ bytes

# %%
report.describe()
# Out:
#              MATHS    ENGLISH   SCIENCE        EVS     HINDI
# count    17.000000  15.000000  15.00000  15.000000  15.00000
# mean    140.411765  73.333333  72.60000  74.133333  80.60000
# std     261.715270  15.559410   6.79075   7.317949  14.20161
# min      60.000000  45.000000  60.00000  58.000000  54.00000
# 25%      67.000000  66.000000  69.50000  70.500000  76.00000
# 50%      76.000000  74.000000  73.00000  76.000000  80.00000
# 75%      89.000000  86.500000  75.50000  76.500000  91.00000
# max    1155.000000  98.000000  90.00000  87.000000  98.00000

# %%
report.head()
# Out:
#            NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 0         GAURI     69     80.0     70.0  72.0   60.0
# 1        MUSKAN     89     98.0     90.0  76.0   92.0
# 2        ANJALI     76     72.0     74.0  76.0   98.0
# 3        ARMAAN     76     74.0     73.0  73.0   76.0
# 4  ANJALI YADAV     74     87.0     76.0  71.0   98.0

# %%
report.tail()
# Out:
#        NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 12    KRITI     67     89.0     60.0  78.0   78.0
# 13  ANAMIKA     98     67.0     78.0  87.0   98.0
# 14   SARIKA     90     45.0     75.0  87.0   60.0
# 15      NaN     77      NaN      NaN   NaN    NaN
# 16      NaN   1155      NaN      NaN   NaN    NaN

# %%
report.shape
# Out:
# (17, 6)

# %%
report.columns.tolist()
# Out:
# ['NAME', 'MATHS', 'ENGLISH', 'SCIENCE', 'EVS', 'HINDI']

# %%
report.iloc[6]
# Out:
# NAME       NANDANI
# MATHS           98
# ENGLISH       89.0
# SCIENCE       76.0
# EVS           76.0
# HINDI         54.0
# Name: 6, dtype: object

# %%
report.iloc[[7,10]]
# Out:
#         NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 7       IRAM     87     69.0     67.0  58.0   76.0
# 10  RITAKSHI     65     86.0     69.0  70.0   87.0

# %%
report.iloc[[3,5,4,7]]
# Out:
#            NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 3        ARMAAN     76     74.0     73.0  73.0   76.0
# 5        AREEBA     76     50.0     65.0  77.0   76.0
# 4  ANJALI YADAV     74     87.0     76.0  71.0   98.0
# 7          IRAM     87     69.0     67.0  58.0   76.0

# %%
report.iloc[5:11]
# Out:
#         NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 5     AREEBA     76     50.0     65.0  77.0   76.0
# 6    NANDANI     98     89.0     76.0  76.0   54.0
# 7       IRAM     87     69.0     67.0  58.0   76.0
# 8     AASTHA     65     65.0     75.0  68.0   86.0
# 9     RITIMA     60     53.0     71.0  67.0   90.0
# 10  RITAKSHI     65     86.0     69.0  70.0   87.0

# %%
report.iloc[10:15]
# Out:
#         NAME  MATHS  ENGLISH  SCIENCE   EVS  HINDI
# 10  RITAKSHI     65     86.0     69.0  70.0   87.0
# 11      JAYA     65     76.0     70.0  76.0   80.0
# 12     KRITI     67     89.0     60.0  78.0   78.0
# 13   ANAMIKA     98     67.0     78.0  87.0   98.0
# 14    SARIKA     90     45.0     75.0  87.0   60.0

# %%
report.iloc[:3,[1,2,3]]
# Out:
#    MATHS  ENGLISH  SCIENCE
# 0     69     80.0     70.0
# 1     89     98.0     90.0
# 2     76     72.0     74.0

# %%
report['ENGLISH']
# Out:
# 0     80.0
# 1     98.0
# 2     72.0
# 3     74.0
# 4     87.0
# 5     50.0
# 6     89.0
# 7     69.0
# 8     65.0
# 9     53.0
# 10    86.0
# 11    76.0
# 12    89.0
# 13    67.0
# 14    45.0
# 15     NaN
# 16     NaN
# Name: ENGLISH, dtype: float64

# %%
report['HINDI']
# Out:
# 0     60.0
# 1     92.0
# 2     98.0
# 3     76.0
# 4     98.0
# 5     76.0
# 6     54.0
# 7     76.0
# 8     86.0
# 9     90.0
# 10    87.0
# 11    80.0
# 12    78.0
# 13    98.0
# 14    60.0
# 15     NaN
# 16     NaN
# Name: HINDI, dtype: float64

# %%
cols_to_see =['ENGLISH','EVS','MATHS']
report[cols_to_see]
# Out:
#     ENGLISH   EVS  MATHS
# 0      80.0  72.0     69
# 1      98.0  76.0     89
# 2      72.0  76.0     76
# 3      74.0  73.0     76
# 4      87.0  71.0     74
# 5      50.0  77.0     76
# 6      89.0  76.0     98
# 7      69.0  58.0     87
# 8      65.0  68.0     65
# 9      53.0  67.0     60
# 10     86.0  70.0     65
# 11     76.0  76.0     65
# 12     89.0  78.0     67
# 13     67.0  87.0     98
# 14     45.0  87.0     90
# 15      NaN   NaN     77
# 16      NaN   NaN   1155

# %%
report[['NAME','MATHS','HINDI']]
# Out:
#             NAME  MATHS  HINDI
# 0          GAURI     69   60.0
# 1         MUSKAN     89   92.0
# 2         ANJALI     76   98.0
# 3         ARMAAN     76   76.0
# 4   ANJALI YADAV     74   98.0
# 5         AREEBA     76   76.0
# 6        NANDANI     98   54.0
# 7           IRAM     87   76.0
# 8         AASTHA     65   86.0
# 9         RITIMA     60   90.0
# 10      RITAKSHI     65   87.0
# 11          JAYA     65   80.0
# 12         KRITI     67   78.0
# 13       ANAMIKA     98   98.0
# 14        SARIKA     90   60.0
# 15           NaN     77    NaN
# 16           NaN   1155    NaN

# %%
report[['ENGLISH','HINDI','SCIENCE','MATHS','EVS']].sum(axis=1)
# Out:
# 0      351.0
# 1      445.0
# 2      396.0
# 3      372.0
# 4      406.0
# 5      344.0
# 6      393.0
# 7      357.0
# 8      359.0
# 9      341.0
# 10     377.0
# 11     367.0
# 12     372.0
# 13     428.0
# 14     357.0
# 15      77.0
# 16    1155.0
# dtype: float64

# %%
report['total']=report[['ENGLISH','MATHS','EVS','HINDI','SCIENCE']].sum(axis=1)

# %%
report['percent'] = report['total']/5

# %%
report.plot(kind='bar',
x='NAME',y='percent',figsize=(15,5),title='Percentage of marks',color=['blue','cyan'])
# Out:
# <AxesSubplot:title={'center':'Percentage of marks'}, xlabel='NAME'>

# %%
report.ENGLISH,HINDI.plot(kind='hist',figsize=(10,6),title='marks dist.in ENGLISH', bins=16,color='orange','blue')
# Out:
#   Input In [23]
#     report.ENGLISH,HINDI.plot(kind='hist',figsize=(10,6),title='marks dist.in ENGLISH', bins=16,color='orange','blue')
#                                                                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
report.plot(
            kind='line',
            x='NAME',
            y=['ENGLISH','HINDI'],
            rot=45,
            figsize=(25,5),
            xticks=range(15),
            marker='s',
            linewidth=3,
            linestyle=':'
            )
# Out:
# <AxesSubplot:xlabel='NAME'>

# %%
report.plot(
            kind='area',
            x='NAME',
            y=['ENGLISH','HINDI'],
            rot=45,
            figsize=(25,5),
            xticks=range(15),
            stacked=False,
            )
# Out:
# <AxesSubplot:xlabel='NAME'>
